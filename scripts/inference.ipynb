# %% [markdown]
# ``` bash
# brew install cmake wget
# xcode-select --install  # if not already done
#
# ## then run this to install
# CMAKE_ARGS="-DLLAMA_METAL=on" FORCE_CMAKE=1 pip install --force-reinstall llama-cpp-python --no-binary :all:
#
# ```

# %%
from llama_cpp import Llama

import gc

llm = Llama(
    model_path="/Users/deepesh/llms/mistral-nemo-15.gguf",
    n_ctx=8192,
    n_threads=6,
    n_gpu_layers=-1,   # Lower GPU pressure
    verbose=True       # Show load/gen timing
)

prompt = "You are a helpful agent. You are Yeti. You are currently slow, but we're working on it."

print("🧠 Response:")
for chunk in llm(prompt, max_tokens=50, stream=True):
    print(chunk["choices"][0]["text"], end="", flush=True)
del llm
gc.collect()
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M2 Pro) - 10922 MiB free
# llama_model_loader: loaded meta data with 39 key-value pairs and 363 tensors from /Users/deepesh/llms/mistral-nemo-15.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Models Mistralai Mistral Nemo Instruc...
# llama_model_loader: - kv   3:                            general.version str              = 2407
# llama_model_loader: - kv   4:                           general.finetune str              = Instruct
# llama_model_loader: - kv   5:                           general.basename str              = models-mistralai-Mistral-Nemo
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import gc
# ----> 2 del llm
#       4 gc.collect()
#
# NameError: name 'llm' is not defined
